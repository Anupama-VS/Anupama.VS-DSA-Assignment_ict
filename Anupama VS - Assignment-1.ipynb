# %% [markdown]
# #1 Read data set to python

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
data= pd.read_excel('C:/Users/USER/Downloads/iris.xls')
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# #2 Display the columns in the dataset

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# #3 calculate the mean of each column of the dataset

# %%
mean_data1=data['SL'].mean()
print('mean of SL = ',mean_data1)
mean_data1=data['SW'].mean()
print('mean of SW = ',mean_data1)
mean_data1=data['PL'].mean()
print('mean of PL = ',mean_data1)
mean_data1=data['PW'].mean()
print('mean of PW = ',mean_data1)
# Out:
# mean of SL =  5.843333333333335
# mean of SW =  3.0540000000000007
# mean of PL =  3.7586666666666693
# mean of PW =  1.1986666666666672

# %% [markdown]
# #4 Check for null values present in the dataset

# %%
data2.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# #5 Meaningful visualizations using dataset

# %%
plt.bar(data['SL'],data['SW'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure()
plt.hist((data['SL'],data['SW']),rwidth=.5)
plt.title('Sepal length & Sepal width',fontsize=16)
plt.show()

# %%
data.dtypes
# Out:
# SL                float64
# SW                float64
# PL                float64
# PW                float64
# Classification     object
# dtype: object

# %%
data[['PL','PW']].plot.hist()
plt.title('Petal length & Petal width',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Petal length & Petal width')

# %%
data[['SL','PL']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure(figsize=(6,4))
plt.scatter(data['SW'],data['PW'],s=15)
plt.title('Plot of SW vs PW')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.subplot(2,1,1)
plt.scatter(data['SL'],data['PL'],s=20)
plt.title('Plot of SL vs PL')
plt.xlabel('Sepal Length')
plt.ylabel('Petal length')

plt.subplot(2,1,2)
plt.scatter(data['SW'],data['PW'],s=20)
plt.title('Plot of SW vs PW')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')

plt.tight_layout()
